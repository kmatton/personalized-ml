# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../src/generic')
import csv
import os
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()

# %%
from results.process_results import ResultProcessor

# %%
main_result_dir = "/data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf"

# %% [markdown]
# ### Result where full model is trained

# %%
base_result_dir = os.path.join(main_result_dir, "from_tokens", "train_all_clf_from_tokens_category_split")
levels = ["seed"]
ft_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_tokens/train_all_clf_from_tokens_category_split: Found results for 3 seeds

# %%
ft_results.results_df
# Out:
#    Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# 0            0.6875          0.102564          0.404494          0.346715
# 1            0.4375          0.153846          0.471910          0.576642
# 2            0.1875          0.256410          0.292135          0.580292
#
#    Books_4_accuracy  Books_accuracy  Books_loss  Books_runtime  Books_samples  \
# 0          0.917526           0.680    0.765965         6.6456           1000
# 1          0.785223           0.670    0.762262         6.6768           1000
# 2          0.823024           0.677    0.755637         6.6686           1000
#
#    Books_samples_per_second  ...  train_loss  train_runtime  train_samples  \
# 0                   150.475  ...    0.729451       468.5849          10000
# 1                   149.771  ...    0.727529       309.2230          10000
# 2                   149.958  ...    0.704259       309.5559          10000
#
# ...

# %%
acc_cols = [col for col in ft_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = ft_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean            0.4375          0.170940          0.389513          0.501217
# std             0.2500          0.078335          0.090819          0.133814
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean          0.841924        0.675667                             0.601852
# std           0.068146        0.005132                             0.042431
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                             0.151515
# std                              0.114391
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                             0.420833
# std                              0.028868
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                             0.349020
# std                              0.098665
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %%
# 3 epochs instead of 2
base_result_dir = os.path.join(main_result_dir, "from_tokens", "train_all_clf_from_tokens_category_split_3_epochs")
levels = ["seed"]
ft3_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_tokens/train_all_clf_from_tokens_category_split_3_epochs: Found results for 3 seeds

# %%
acc_cols = [col for col in ft3_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = ft3_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean          0.229167          0.170940          0.471910          0.636253
# std           0.190941          0.039167          0.151997          0.014750
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean          0.699313        0.633667                             0.481481
# std           0.024055        0.017039                             0.162763
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                             0.121212
# std                              0.069433
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                             0.450000
# std                              0.184137
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                             0.423529
# std                              0.020377
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %% [markdown]
# ### Using Raw DistilBERT Embeddings

# %%
base_result_dir = os.path.join(main_result_dir, "from_embeds", "train_all_product_split_from_distilbert_embeds")
levels = ["seed"]
ft_db_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/train_all_product_split_from_distilbert_embeds: Found results for 3 seeds

# %%
acc_cols = [col for col in ft_db_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = ft_db_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean               0.0               0.0               0.0               0.0
# std                0.0               0.0               0.0               0.0
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean               1.0           0.582                                  0.0
# std                0.0           0.000                                  0.0
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %% [markdown]
# ### Using DIstilBERT Embeddings Pre-trained on CLF task

# %%
base_result_dir = os.path.join(main_result_dir, "from_embeds", "train_all_product_split_from_product_split_clf_embeddings")
levels = ["seed"]
ft_db_results = ResultProcessor(base_result_dir, levels, verbose=True)

# %% [markdown]
# ## Results for Incorrect Clf Layer Params

# %% [markdown]
# ### Result where we go from pre-trained embeddings to labels
#
# 1) Use user split embeddings

# %%
# pre-trained embeddings are from model trained on user-split train data

# %%
base_result_dir = os.path.join(main_result_dir, "from_embeds", "train_all_from_clf_embeds_product_category_split")
levels = ["seed"]
fe_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/train_all_from_clf_embeds_product_category_split: Found results for 3 seeds

# %%
acc_cols = [col for col in fe_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = fe_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean               0.0               0.0          0.116105          0.131387
# std                0.0               0.0          0.017163          0.003650
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean          0.986254        0.620333                                  0.0
# std           0.000000        0.001155                                  0.0
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                             0.020833
# std                              0.014434
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                             0.072549
# std                              0.008985
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %%
fe_results.train_hist_df
# Out:
#      step   data      loss seed
# 0       1  train  1.552400   42
# 1       2  train  1.556900   42
# 2       3  train  1.528900   42
# 3       4  train  1.567100   42
# 4       5  train  1.625200   42
# ..    ...    ...       ...  ...
# 622   623  train  1.103100   44
# 623   624  train  0.858500   44
# 624   625  train  1.048400   44
# 625   626  train  1.134600   44
# 626   500    val  0.924824   44
#
# [1881 rows x 4 columns]

# %%
sns.lineplot(data=fe_results.train_hist_df, x='step', y='loss')
# Out:
# <AxesSubplot:xlabel='step', ylabel='loss'>

# %%
sns.lineplot(data=ft_results.train_hist_df, x='step', y='loss')
# Out:
# <AxesSubplot:xlabel='step', ylabel='loss'>

# %% [markdown]
# ### Result where we go from pre-trained embeddings to labels
#
# 2) Use user split embeddings use the embeddings from this task (sanity check)

# %%
base_result_dir = os.path.join(main_result_dir, "from_embeds", "train_all_from_clf_embeds_product_category_split_embeds_from_product_model")
levels = ["seed"]
fe_pm_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/train_all_from_clf_embeds_product_category_split_embeds_from_product_model: Found results for 3 seeds

# %%
acc_cols = [col for col in fe_pm_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = fe_pm_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean               0.0               0.0          0.074906          0.131387
# std                0.0               0.0          0.012974          0.003650
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean          0.979954           0.613                             0.037037
# std           0.002625           0.002                             0.016038
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                               0.0250
# std                                0.0125
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                             0.033333
# std                              0.003396
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %%
sns.lineplot(data=fe_pm_results.train_hist_df, x='step', y='loss')
# Out:
# <AxesSubplot:xlabel='step', ylabel='loss'>

# %% [markdown]
# ### Result where we from pre-trained embeddings (unmodified distilbert) to labels
#
# * performance is much worse! model just learn to predict the majority class

# %%
base_result_dir = os.path.join(main_result_dir, "from_embeds", "train_all_from_clf_embeds_product_category_split_embeds_from_distilbert")
levels = ["seed"]
fe_db_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/train_all_from_clf_embeds_product_category_split_embeds_from_distilbert: Found results for 3 seeds

# %%
acc_cols = [col for col in fe_db_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = fe_db_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean               0.0               0.0               0.0               0.0
# std                0.0               0.0               0.0               0.0
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean               1.0           0.582                                  0.0
# std                0.0           0.000                                  0.0
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %%
sns.lineplot(data=fe_db_results.train_hist_df, x='step', y='loss')
# Out:
# <AxesSubplot:xlabel='step', ylabel='loss'>

# %%
# same thing but more epochs and more complex classification network
base_result_dir = os.path.join(main_result_dir, "from_embeds", "train_all_distilbert_embeds_product_category_split_larger_net")
levels = ["seed"]
fe_db2_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/train_all_distilbert_embeds_product_category_split_larger_net: Found results for 3 seeds

# %%
acc_cols = [col for col in fe_db2_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = fe_db2_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean               0.0               0.0               0.0               0.0
# std                0.0               0.0               0.0               0.0
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean               1.0           0.582                                  0.0
# std                0.0           0.000                                  0.0
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                                  0.0
# std                                   0.0
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %%
sns.lineplot(data=fe_db2_results.train_hist_df, x='step', y='loss')
# Out:
# <AxesSubplot:xlabel='step', ylabel='loss'>
