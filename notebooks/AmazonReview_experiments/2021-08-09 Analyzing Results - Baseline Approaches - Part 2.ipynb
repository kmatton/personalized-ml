# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../src/generic')
import csv
import os
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()

# %%
from results.process_results import ResultProcessor

# %%
main_result_dir = "/data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf"

# %% [markdown]
# ## Category Split 1 (Books, Movie and TV, Grocery, Pantry)

# %%
base_result_dir = os.path.join(main_result_dir, "train_grocery_test_media_category_split")
levels = ["seed"]
train_grocery_test_media_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_grocery_test_media_category_split: Found results for 5 seeds

# %%
acc_cols = [col for col in train_grocery_test_media_results.results_df if "accuracy" in col]
train_grocery_test_media_results.results_df.agg(["mean", "std"])["Movies_and_TV_accuracy"]
# Out:
# mean    0.622200
# std     0.007014
# Name: Movies_and_TV_accuracy, dtype: float64

# %%
base_result_dir = os.path.join(main_result_dir, "train_books_test_food_small_category_split")
levels = ["seed"]
train_books_test_food_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_books_test_food_small_category_split: Found results for 5 seeds

# %%
acc_cols = [col for col in train_books_test_food_results.results_df if "accuracy" in col]
train_books_test_food_results.results_df.agg(["mean", "std"])["Prime_Pantry_accuracy"]
# Out:
# mean    0.722000
# std     0.030092
# Name: Prime_Pantry_accuracy, dtype: float64

# %%
base_result_dir = os.path.join(main_result_dir, "train_all_random_subset_category_split")
levels = ["seed"]
train_random_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_all_random_subset_category_split: Found results for 5 seeds

# %%
acc_cols = [col for col in train_random_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = train_random_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean          0.137500          0.087179          0.429213          0.387591
# std           0.184349          0.130240          0.101560          0.129714
#
#       Books_4_accuracy  Books_accuracy  Grocery_and_Gourmet_Food_0_accuracy  \
# mean          0.862199        0.651800                             0.322222
# std           0.067114        0.007694                             0.237008
#
#       Grocery_and_Gourmet_Food_1_accuracy  \
# mean                             0.045455
# std                              0.078730
#
#       Grocery_and_Gourmet_Food_2_accuracy  \
# mean                             0.497500
# std                              0.146948
#
#       Grocery_and_Gourmet_Food_3_accuracy  \
# mean                             0.209412
# std                              0.105112
#
#       Grocery_and_Gourmet_Food_4_accuracy  Grocery_and_Gourmet_Food_accuracy  \
# ...

# %% [markdown]
# ## Category Split 2 (Books, Movie and TV, Home and Kitchen, Tools and Home Improvement)

# %%
base_result_dir = os.path.join(main_result_dir, "train_all_small_category_split2")
levels = ["seed"]
train_all_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_all_small_category_split2: Found results for 5 seeds

# %%
acc_cols = [col for col in train_all_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = train_all_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean          0.544000          0.489000          0.494000          0.630000
# std           0.064556          0.063482          0.059097          0.067915
#
#       Books_4_accuracy  Books_accuracy  Home_and_Kitchen_0_accuracy  \
# mean          0.569000        0.545200                     0.597000
# std           0.114532        0.012558                     0.041923
#
#       Home_and_Kitchen_1_accuracy  Home_and_Kitchen_2_accuracy  \
# mean                     0.471000                      0.47200
# std                      0.074783                      0.05552
#
#       Home_and_Kitchen_3_accuracy  Home_and_Kitchen_4_accuracy  \
# mean                     0.587000                     0.590000
# std                      0.086934                     0.105297
#
#       Home_and_Kitchen_accuracy  Movies_and_TV_0_accuracy  \
# mean                   0.543400                  0.653000
# ...

# %%
base_result_dir = os.path.join(main_result_dir, "train_ID_small_category_split2")
levels = ["category", "seed"]
train_ID_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_ID_small_category_split2: Found results for 4 categorys
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_ID_small_category_split2/Books: Found results for 5 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_ID_small_category_split2/Home_and_Kitchen: Found results for 5 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_ID_small_category_split2/Tools_and_Home_Improvement: Found results for 5 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/train_ID_small_category_split2/Movies_and_TV: Found results for 5 seeds

# %%
acc_cols = [col for col in train_ID_results.results_df if "accuracy" in col]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    results = train_ID_results.results_df.agg(["mean", "std"])[acc_cols]
    display(results)
# Out:
#       Books_0_accuracy  Books_1_accuracy  Books_2_accuracy  Books_3_accuracy  \
# mean          0.587000          0.467000          0.484000          0.526000
# std           0.098018          0.067509          0.054475          0.128423
#
#       Books_4_accuracy  Books_accuracy  eval_0_accuracy  eval_1_accuracy  \
# mean          0.606000        0.534000         0.611500         0.439500
# std           0.094366        0.011979         0.108835         0.090987
#
#       eval_2_accuracy  eval_3_accuracy  eval_4_accuracy  eval_accuracy  \
# mean         0.429750         0.435750         0.628750       0.509050
# std          0.077739         0.086134         0.102211       0.034447
#
#       test_0_accuracy  test_1_accuracy  test_2_accuracy  test_3_accuracy  \
# mean         0.590250         0.427000         0.445000         0.488500
# std          0.123698         0.092841         0.082318         0.101659
#
#       test_4_accuracy  test_accuracy  Home_and_Kitchen_0_accuracy  \
# ...
