# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../src/generic')
import csv
import os
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()
from sklearn.metrics import log_loss

# %%
from results.process_results import ResultProcessor

# %%
main_result_dir = "/data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf"

# %% [markdown]
# ## Naive Baselines

# %%
data_dir = "/data/ddmg/redditlanguagemodeling/data/AmazonReviews/data"

# %%
data_df = pd.read_csv(os.path.join(data_dir, 'amazon_v2.0/reviews.csv'),
                      dtype={'reviewerID':str, 'asin':str, 'reviewTime':str,'unixReviewTime':int,
                             'reviewText':str,'summary':str,'verified':bool,'category':str, 'reviewYear':int},
                      keep_default_na=False, na_values=[], quoting=csv.QUOTE_NONNUMERIC)

# %%
split_df = pd.read_csv(os.path.join(data_dir, 'amazon_v2.0', 'splits', 'my_user_split.csv'))

# %%
# get select people
select_file = "/data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500/selected_people.txt"
with open(select_file, 'r') as f:
    people = f.read().splitlines()

# %%
data_df["split"] = split_df["split"]

# %%
select_df = data_df[data_df["reviewerID"].isin(people)]
len(select_df)
# Out:
# 140326

# %%
test_df = select_df[split_df["split"] == 2]
# Out:
# <ipython-input-11-0e99ae5568ce>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test_df = select_df[split_df["split"] == 2]

# %%
train_df = select_df[split_df["split"] == 0]
# Out:
# <ipython-input-12-889f06942d9b>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   train_df = select_df[split_df["split"] == 0]

# %%
def count_1(x):
    return sum(x == 1)

count_1.__name__ = "count_1"

def count_2(x):
    return sum(x == 2)

count_2.__name__ = "count_2"

def count_3(x):
    return sum(x == 3)

count_3.__name__ = "count_3"

def count_4(x):
    return sum(x == 4)

count_4.__name__ = "count_4"

def count_5(x):
    return sum(x == 5)

count_5.__name__ = "count_5"

# %%
count_fns = [count_1, count_2, count_3, count_4, count_5]

# %%
train_dist_by_user = train_df[["reviewerID", "overall"]].groupby(["reviewerID"]).agg(count_fns)
train_dist_by_user
# Out:
#                overall
#                count_1 count_2 count_3 count_4 count_5
# reviewerID
# A101S5PLO0VRHQ     5.0    29.0    20.0    24.0    25.0
# A10E0V7PGY34UZ     0.0     0.0     0.0     4.0    41.0
# A10O7THJ2O20AG     1.0     0.0     1.0     0.0    43.0
# A11P853U6FIKAM     0.0     5.0    18.0    61.0    82.0
# A12O5K3EQ4MC7Z     1.0     2.0    24.0    61.0    61.0
# ...                ...     ...     ...     ...     ...
# AYT4FJYVCHYLE      0.0     2.0     9.0    24.0    10.0
# AYVW3O6W8S5S4      0.0     0.0     8.0    23.0    14.0
# AZD488SA9QMYF      0.0     0.0     0.0     3.0    42.0
# AZJ4DFLH9O4FZ      0.0     0.0     3.0    15.0    27.0
# AZZV9PDNMCOZW      3.0     0.0     7.0    16.0    19.0
#
# [500 rows x 5 columns]

# %%
test_dist_by_user = test_df[["reviewerID", "overall"]].groupby(["reviewerID"]).agg(count_fns)
test_dist_by_user
# Out:
#                overall
#                count_1 count_2 count_3 count_4 count_5
# reviewerID
# A101S5PLO0VRHQ     2.0    11.0    11.0     5.0     6.0
# A10E0V7PGY34UZ     0.0     0.0     0.0     1.0    14.0
# A10O7THJ2O20AG     1.0     0.0     1.0     1.0    12.0
# A11P853U6FIKAM     1.0     0.0    10.0    22.0    24.0
# A12O5K3EQ4MC7Z     0.0     0.0    10.0    21.0    20.0
# ...                ...     ...     ...     ...     ...
# AYT4FJYVCHYLE      0.0     1.0     2.0     5.0     7.0
# AYVW3O6W8S5S4      0.0     1.0     2.0     8.0     4.0
# AZD488SA9QMYF      0.0     0.0     0.0     1.0    14.0
# AZJ4DFLH9O4FZ      0.0     0.0     4.0     6.0     5.0
# AZZV9PDNMCOZW      1.0     2.0     2.0     2.0     8.0
#
# [500 rows x 5 columns]

# %%
test_score_df = test_df[["reviewerID", "overall"]]

# %% [markdown]
# ### Predict Test Distr. Baseline

# %%
# for each user predict test probs
users = []
perfs = []
for user, row in test_dist_by_user.iterrows():
    user_gt = test_df[test_df["reviewerID"] == user]["overall"].values
    score_counts = np.array([row["overall", "count_{}".format(i + 1)] for i in range(5)])
    norm_score_counts = np.expand_dims(score_counts / sum(score_counts), axis=0)
    preds = np.repeat(norm_score_counts, len(user_gt), axis=0)
    loss = log_loss(user_gt, preds, labels=np.arange(5) + 1)
    users.append(user)
    perfs.append(loss)

# %%
test_prob_df = pd.DataFrame({"reviewerID": users, "perf": perfs})

# %%
test_prob_df
# Out:
#          reviewerID      perf
# 0    A101S5PLO0VRHQ  1.471413
# 1    A10E0V7PGY34UZ  0.244930
# 2    A10O7THJ2O20AG  0.720125
# 3    A11P853U6FIKAM  1.107927
# 4    A12O5K3EQ4MC7Z  1.051915
# ..              ...       ...
# 495   AYT4FJYVCHYLE  1.171060
# 496   AYVW3O6W8S5S4  1.136917
# 497   AZD488SA9QMYF  0.244930
# 498   AZJ4DFLH9O4FZ  1.085189
# 499   AZZV9PDNMCOZW  1.321756
#
# [500 rows x 2 columns]

# %%
print(test_prob_df.mean())
print(test_prob_df.std())
print(test_prob_df.quantile(q=[.2, .4, .6, .8, 1]))
# Out:
# perf    0.790699
# dtype: float64
# perf    0.388399
# dtype: float64
#          perf
# 0.2  0.481677
# 0.4  0.696330
# 0.6  0.927617
# 0.8  1.136917
# 1.0  1.586785

# %% [markdown]
# ### Predict Train Distr. Baseline

# %%
users2 = []
perfs2 = []
for user, row in train_dist_by_user.iterrows():
    user_gt = test_df[test_df["reviewerID"] == user]["overall"].values
    score_counts = np.array([row["overall", "count_{}".format(i + 1)] for i in range(5)])
    norm_score_counts = np.expand_dims(score_counts / sum(score_counts), axis=0)
    preds = np.repeat(norm_score_counts, len(user_gt), axis=0)
    loss = log_loss(user_gt, preds, labels=np.arange(5) + 1)
    users2.append(user)
    perfs2.append(loss)

# %%
train_prob_df = pd.DataFrame({"reviewerID": users2, "perf": perfs2})

# %%
train_prob_df
# Out:
#          reviewerID      perf
# 0    A101S5PLO0VRHQ  1.537137
# 1    A10E0V7PGY34UZ  0.248242
# 2    A10O7THJ2O20AG  2.846510
# 3    A11P853U6FIKAM  1.679051
# 4    A12O5K3EQ4MC7Z  1.075978
# ..              ...       ...
# 495   AYT4FJYVCHYLE  1.333598
# 496   AYVW3O6W8S5S4  3.202199
# 497   AZD488SA9QMYF  0.244930
# 498   AZJ4DFLH9O4FZ  1.331867
# 499   AZZV9PDNMCOZW  5.631536
#
# [500 rows x 2 columns]

# %%
print(train_prob_df.mean())
print(train_prob_df.std())
print(train_prob_df.quantile(q=[.2, .4, .6, .8, 1]))
# Out:
# perf    1.156198
# dtype: float64
# perf    0.966114
# dtype: float64
#          perf
# 0.2  0.527940
# 0.4  0.840569
# 0.6  1.094182
# 0.8  1.468325
# 1.0  7.833139

# %% [markdown]
# ### Train Majority Class Baseline

# %%
user_maj_cls_train = train_df.groupby(["reviewerID"])[["overall"]].agg(lambda x: x.value_counts().index[0])
# predict that for test data
users = []
perfs = []
for user, row in user_maj_cls_train.iterrows():
    user_gt = test_df[test_df["reviewerID"] == user]["overall"].values
    pred_score = row["overall"]
    acc = sum(user_gt == pred_score) / len(user_gt)
    users.append(user)
    perfs.append(acc)
train_mc_df = pd.DataFrame({"reviewerID": users, "perf": perfs})
train_mc_df
# Out:
#          reviewerID      perf
# 0    A101S5PLO0VRHQ  0.314286
# 1    A10E0V7PGY34UZ  0.933333
# 2    A10O7THJ2O20AG  0.800000
# 3    A11P853U6FIKAM  0.421053
# 4    A12O5K3EQ4MC7Z  0.392157
# ..              ...       ...
# 495   AYT4FJYVCHYLE  0.333333
# 496   AYVW3O6W8S5S4  0.533333
# 497   AZD488SA9QMYF  0.933333
# 498   AZJ4DFLH9O4FZ  0.333333
# 499   AZZV9PDNMCOZW  0.533333
#
# [500 rows x 2 columns]

# %%
print(train_mc_df.mean())
print(train_mc_df.std())
print(train_mc_df.quantile(q=[.2, .4, .6, .8, 1]))
# Out:
# perf    0.629733
# dtype: float64
# perf    0.219778
# dtype: float64
#          perf
# 0.2  0.411132
# 0.4  0.545455
# 0.6  0.679622
# 0.8  0.866667
# 1.0  1.000000

# %% [markdown]
# ### Test Majority Class Baseline

# %%
test_mc_df = test_df.groupby(["reviewerID"])[["overall"]].agg(lambda x: x.value_counts(normalize=True).iloc[0])

# %%
print(test_mc_df.mean())
print(test_mc_df.std())
print(test_mc_df.quantile(q=[.2, .4, .6, .8, 1]))
# Out:
# overall    0.650542
# dtype: float64
# overall    0.195295
# dtype: float64
#       overall
# 0.2  0.466667
# 0.4  0.577671
# 0.6  0.686352
# 0.8  0.866667
# 1.0  1.000000

# %% [markdown]
# ### Global Model

# %%
base_result_dir = os.path.join(main_result_dir, "from_embeds", "eval_global_model_early_stopping_across_users")
levels = ["train_seed", "eval_seed"]
global_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/eval_global_model_early_stopping_across_users: Found results for 3 train_seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/eval_global_model_early_stopping_across_users/43: Found results for 1 eval_seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/eval_global_model_early_stopping_across_users/44: Found results for 1 eval_seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/eval_global_model_early_stopping_across_users/42: Found results for 1 eval_seeds

# %%
# collect results by user
all_results = []
for col in global_results.results_df.columns:
    results = global_results.results_df[col].values
    if col[0] == 'A':
        for val, seed in zip(results, [43, 44, 42]):
            result_dict = {}
            result_dict["user"] = col.split("_")[0]
            result_dict["result"] = "_".join(col.split("_")[1:])
            result_dict["val"] = val
            result_dict["seed"] = seed
            all_results.append(result_dict)

# %%
global_df = pd.DataFrame(all_results)
global_df
# Out:
#                  user      result       val  seed
# 0      A101S5PLO0VRHQ  0_accuracy  0.000000    43
# 1      A101S5PLO0VRHQ  0_accuracy  0.000000    44
# 2      A101S5PLO0VRHQ  0_accuracy  0.000000    42
# 3      A101S5PLO0VRHQ  1_accuracy  0.272727    43
# 4      A101S5PLO0VRHQ  1_accuracy  0.272727    44
# ...               ...         ...       ...   ...
# 14053  A39IY0JU5JI69G  0_accuracy       NaN    44
# 14054  A39IY0JU5JI69G  0_accuracy       NaN    42
# 14055  A3DFMKBGQT9QIH  1_accuracy       NaN    43
# 14056  A3DFMKBGQT9QIH  1_accuracy       NaN    44
# 14057  A3DFMKBGQT9QIH  1_accuracy       NaN    42
#
# [14058 rows x 4 columns]

# %%
global_df2 = global_df.groupby(["user", "result"]).agg(["mean", "std"])["val"].reset_index()
global_df2
# Out:
#                 user              result         mean        std
# 0     A101S5PLO0VRHQ          0_accuracy     0.000000   0.000000
# 1     A101S5PLO0VRHQ          1_accuracy     0.303030   0.052486
# 2     A101S5PLO0VRHQ          2_accuracy     0.757576   0.052486
# 3     A101S5PLO0VRHQ          3_accuracy     0.800000   0.000000
# 4     A101S5PLO0VRHQ          4_accuracy     0.166667   0.000000
# ...              ...                 ...          ...        ...
# 4681   AZZV9PDNMCOZW                loss     1.092888   0.043024
# 4682   AZZV9PDNMCOZW             runtime     0.014167   0.000404
# 4683   AZZV9PDNMCOZW             samples    15.000000   0.000000
# 4684   AZZV9PDNMCOZW  samples_per_second  1060.722667  29.035503
# 4685   AZZV9PDNMCOZW    steps_per_second    70.715000   1.935570
#
# [4686 rows x 4 columns]

# %%
global_df2 = global_df2.pivot(index='user', columns='result', values=['mean', 'std'])
global_df2
# Out:
#                      mean                                              \
# result         0_accuracy 1_accuracy 2_accuracy 3_accuracy 4_accuracy
# user
# A101S5PLO0VRHQ        0.0    0.30303   0.757576   0.800000   0.166667
# A10E0V7PGY34UZ        NaN        NaN        NaN   0.000000   1.000000
# A10O7THJ2O20AG        0.0        NaN   0.666667   0.000000   0.666667
# A11P853U6FIKAM        0.0        NaN   0.366667   0.227273   0.833333
# A12O5K3EQ4MC7Z        NaN        NaN   0.600000   0.841270   0.716667
# ...                   ...        ...        ...        ...        ...
# AYT4FJYVCHYLE         NaN    0.00000   0.500000   0.600000   0.857143
# AYVW3O6W8S5S4         NaN    0.00000   0.000000   0.125000   1.000000
# AZD488SA9QMYF         NaN        NaN        NaN   1.000000   0.928571
# AZJ4DFLH9O4FZ         NaN        NaN   0.500000   0.722222   0.600000
# AZZV9PDNMCOZW         0.0    0.50000   0.500000   0.500000   0.708333
#
#                                                                          ...  \
# result          accuracy      loss   runtime samples samples_per_second  ...
# user                                                                     ...
# A101S5PLO0VRHQ  0.476190  1.120820  0.026733    35.0        1308.001333  ...
# A10E0V7PGY34UZ  0.933333  0.384862  0.013967    15.0        1074.945000  ...
# A10O7THJ2O20AG  0.577778  1.242837  0.015267    15.0         998.874000  ...
# A11P853U6FIKAM  0.502924  0.935463  0.036100    57.0        1579.611667  ...
# A12O5K3EQ4MC7Z  0.745098  0.725279  0.034367    51.0        1487.120667  ...
# ...                  ...       ...       ...     ...                ...  ...
# AYT4FJYVCHYLE   0.666667  0.636464  0.014167    15.0        1059.953667  ...
# AYVW3O6W8S5S4   0.333333  1.614175  0.013867    15.0        1082.509000  ...
# AZD488SA9QMYF   0.933333  0.262011  0.013833    15.0        1085.220667  ...
# AZJ4DFLH9O4FZ   0.622222  0.609930  0.014333    15.0        1047.548333  ...
# AZZV9PDNMCOZW   0.577778  1.092888  0.014167    15.0        1060.722667  ...
#
#                       std                                             \
# result         1_accuracy 2_accuracy 3_accuracy 4_accuracy  accuracy
# user
# A101S5PLO0VRHQ   0.052486   0.052486   0.000000   0.000000  0.016496
# A10E0V7PGY34UZ        NaN        NaN   0.000000   0.000000  0.000000
# A10O7THJ2O20AG        NaN   0.577350   0.000000   0.000000  0.038490
# A11P853U6FIKAM        NaN   0.057735   0.000000   0.000000  0.010129
# A12O5K3EQ4MC7Z        NaN   0.000000   0.027493   0.028868  0.000000
# ...                   ...        ...        ...        ...       ...
# AYT4FJYVCHYLE    0.000000   0.000000   0.000000   0.000000  0.000000
# AYVW3O6W8S5S4    0.000000   0.000000   0.000000   0.000000  0.000000
# AZD488SA9QMYF         NaN        NaN   0.000000   0.000000  0.000000
# AZJ4DFLH9O4FZ         NaN   0.000000   0.096225   0.000000  0.038490
# AZZV9PDNMCOZW    0.000000   0.000000   0.000000   0.072169  0.038490
#
#
# result              loss   runtime samples samples_per_second steps_per_second
# user
# A101S5PLO0VRHQ  0.012142  0.000451     0.0          22.170650         1.266893
# A10E0V7PGY34UZ  0.028398  0.000153     0.0          14.577506         0.971937
# A10O7THJ2O20AG  0.030466  0.002479     0.0         149.499662         9.966971
# A11P853U6FIKAM  0.009915  0.000265     0.0          12.468323         0.437578
# A12O5K3EQ4MC7Z  0.015350  0.001457     0.0          61.878556         2.426665
# ...                  ...       ...     ...                ...              ...
# AYT4FJYVCHYLE   0.019655  0.000379     0.0          31.285691         2.085797
# AYVW3O6W8S5S4   0.035395  0.000306     0.0          20.844639         1.389373
# AZD488SA9QMYF   0.016293  0.000153     0.0          11.056036         0.737032
# AZJ4DFLH9O4FZ   0.028343  0.000666     0.0          46.899888         3.126892
# AZZV9PDNMCOZW   0.043024  0.000404     0.0          29.035503         1.935570
#
# [500 rows x 22 columns]

# %%
global_df2 = global_df2.swaplevel(i=0, j=1, axis=1)
global_df2
# Out:
# result         0_accuracy 1_accuracy 2_accuracy 3_accuracy 4_accuracy  \
#                      mean       mean       mean       mean       mean
# user
# A101S5PLO0VRHQ        0.0    0.30303   0.757576   0.800000   0.166667
# A10E0V7PGY34UZ        NaN        NaN        NaN   0.000000   1.000000
# A10O7THJ2O20AG        0.0        NaN   0.666667   0.000000   0.666667
# A11P853U6FIKAM        0.0        NaN   0.366667   0.227273   0.833333
# A12O5K3EQ4MC7Z        NaN        NaN   0.600000   0.841270   0.716667
# ...                   ...        ...        ...        ...        ...
# AYT4FJYVCHYLE         NaN    0.00000   0.500000   0.600000   0.857143
# AYVW3O6W8S5S4         NaN    0.00000   0.000000   0.125000   1.000000
# AZD488SA9QMYF         NaN        NaN        NaN   1.000000   0.928571
# AZJ4DFLH9O4FZ         NaN        NaN   0.500000   0.722222   0.600000
# AZZV9PDNMCOZW         0.0    0.50000   0.500000   0.500000   0.708333
#
# result          accuracy      loss   runtime samples samples_per_second  ...  \
#                     mean      mean      mean    mean               mean  ...
# user                                                                     ...
# A101S5PLO0VRHQ  0.476190  1.120820  0.026733    35.0        1308.001333  ...
# A10E0V7PGY34UZ  0.933333  0.384862  0.013967    15.0        1074.945000  ...
# A10O7THJ2O20AG  0.577778  1.242837  0.015267    15.0         998.874000  ...
# A11P853U6FIKAM  0.502924  0.935463  0.036100    57.0        1579.611667  ...
# A12O5K3EQ4MC7Z  0.745098  0.725279  0.034367    51.0        1487.120667  ...
# ...                  ...       ...       ...     ...                ...  ...
# AYT4FJYVCHYLE   0.666667  0.636464  0.014167    15.0        1059.953667  ...
# AYVW3O6W8S5S4   0.333333  1.614175  0.013867    15.0        1082.509000  ...
# AZD488SA9QMYF   0.933333  0.262011  0.013833    15.0        1085.220667  ...
# AZJ4DFLH9O4FZ   0.622222  0.609930  0.014333    15.0        1047.548333  ...
# AZZV9PDNMCOZW   0.577778  1.092888  0.014167    15.0        1060.722667  ...
#
# result         1_accuracy 2_accuracy 3_accuracy 4_accuracy  accuracy  \
#                       std        std        std        std       std
# user
# A101S5PLO0VRHQ   0.052486   0.052486   0.000000   0.000000  0.016496
# A10E0V7PGY34UZ        NaN        NaN   0.000000   0.000000  0.000000
# A10O7THJ2O20AG        NaN   0.577350   0.000000   0.000000  0.038490
# A11P853U6FIKAM        NaN   0.057735   0.000000   0.000000  0.010129
# A12O5K3EQ4MC7Z        NaN   0.000000   0.027493   0.028868  0.000000
# ...                   ...        ...        ...        ...       ...
# AYT4FJYVCHYLE    0.000000   0.000000   0.000000   0.000000  0.000000
# AYVW3O6W8S5S4    0.000000   0.000000   0.000000   0.000000  0.000000
# AZD488SA9QMYF         NaN        NaN   0.000000   0.000000  0.000000
# AZJ4DFLH9O4FZ         NaN   0.000000   0.096225   0.000000  0.038490
# AZZV9PDNMCOZW    0.000000   0.000000   0.000000   0.072169  0.038490
#
# result              loss   runtime samples samples_per_second steps_per_second
#                      std       std     std                std              std
# user
# A101S5PLO0VRHQ  0.012142  0.000451     0.0          22.170650         1.266893
# A10E0V7PGY34UZ  0.028398  0.000153     0.0          14.577506         0.971937
# A10O7THJ2O20AG  0.030466  0.002479     0.0         149.499662         9.966971
# A11P853U6FIKAM  0.009915  0.000265     0.0          12.468323         0.437578
# A12O5K3EQ4MC7Z  0.015350  0.001457     0.0          61.878556         2.426665
# ...                  ...       ...     ...                ...              ...
# AYT4FJYVCHYLE   0.019655  0.000379     0.0          31.285691         2.085797
# AYVW3O6W8S5S4   0.035395  0.000306     0.0          20.844639         1.389373
# AZD488SA9QMYF   0.016293  0.000153     0.0          11.056036         0.737032
# AZJ4DFLH9O4FZ   0.028343  0.000666     0.0          46.899888         3.126892
# AZZV9PDNMCOZW   0.043024  0.000404     0.0          29.035503         1.935570
#
# [500 rows x 22 columns]

# %%
global_df2 = global_df2[['accuracy', 'loss']]
global_df2
# Out:
# result          accuracy                loss
#                     mean       std      mean       std
# user
# A101S5PLO0VRHQ  0.476190  0.016496  1.120820  0.012142
# A10E0V7PGY34UZ  0.933333  0.000000  0.384862  0.028398
# A10O7THJ2O20AG  0.577778  0.038490  1.242837  0.030466
# A11P853U6FIKAM  0.502924  0.010129  0.935463  0.009915
# A12O5K3EQ4MC7Z  0.745098  0.000000  0.725279  0.015350
# ...                  ...       ...       ...       ...
# AYT4FJYVCHYLE   0.666667  0.000000  0.636464  0.019655
# AYVW3O6W8S5S4   0.333333  0.000000  1.614175  0.035395
# AZD488SA9QMYF   0.933333  0.000000  0.262011  0.016293
# AZJ4DFLH9O4FZ   0.622222  0.038490  0.609930  0.028343
# AZZV9PDNMCOZW   0.577778  0.038490  1.092888  0.043024
#
# [500 rows x 4 columns]

# %%
global_df2.mean()
# Out:
# result
# accuracy  mean    0.689322
#           std     0.020408
# loss      mean    0.722369
#           std     0.018607
# dtype: float64

# %%
global_df2.std()
# Out:
# result
# accuracy  mean    0.183303
#           std     0.022786
# loss      mean    0.365459
#           std     0.012726
# dtype: float64

# %%
global_df2.quantile(q=[.2, .4, .6, .8, 1])
# Out:
# result  accuracy                loss
#             mean       std      mean       std
# 0.2     0.533333  0.000000  0.414325  0.008161
# 0.4     0.644444  0.001293  0.595947  0.012964
# 0.6     0.737354  0.024054  0.774307  0.018287
# 0.8     0.866667  0.038490  0.996846  0.028578
# 1.0     1.000000  0.138778  2.115849  0.082612

# %% [markdown]
# ### Person-Specific Models

# %%
base_result_dir = os.path.join(main_result_dir, "from_embeds", "person_specific_my_split_n_500_early_stopping")
levels = ["user", "seed"]
ps_results = ResultProcessor(base_result_dir, levels, verbose=True)
# Out:
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping: Found results for 500 users
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2VV2MISGXFY1O: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1XC010CS7NV8Z: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AP4FQR3BIIYEW: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A27HJP68CKWXP5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AKDF3N2SXY3SP: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A26EQ8U96JA92T: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ADVTJ03JD4RQ2: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AZJ4DFLH9O4FZ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A30V9M9DZW8SFU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2L6U1XA9WQR2M: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A9TJ1ZSTUF9BV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3HLUF8W1DCHK9: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AMUP8DYE7EAN2: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2OYA9MEEJEHQG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3QRR8PSCBI07C: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2F1A7DANSLFJ9: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1X6E6VBABKKYB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3QVSY2VOD61F2: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ADSTKO312HFJF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ADTBCTN0DNAIQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2UJTG9XC4KISL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A21SESEJ8E52B7: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A12O5K3EQ4MC7Z: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1AEPMPA12GUJ7: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1DN4LRYC6GXV1: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3R7MXVQRGGIQ9: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A19DAATJSXHVRX: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A30OOWHOPW4U35: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3V1A3C9DTLPME: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3JPCI110IQLG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3R2NW2FW5QSHS: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/APRP8UBWTQ15J: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1B70ZEWQ6UH1A: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AINGNE1J86KTH: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A17ZPB2LS25PUU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3IR7UIVHRX2AD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A284H9L6BMEDPW: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AHEWSXY6YF66X: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A28JD1OHWQEHP7: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2L9D3IM9DSDVE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1BS3PO0EAY1B4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2YNN4X7CCKPNF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A8INT3NMHRUS4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A194K60CWZ371J: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AP0DFP9ODVANR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2K057YIAJJQXS: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2X29H96X7C3XJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ASMF7OU99H1RI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2N5Z2JKJCUPFN: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A13WOT3RSXKRD5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AYVW3O6W8S5S4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1YFB1OF0XKJOD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A37SZWL3R0LEQ3: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3QFDDODG2X2HL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1FYGMRKYQWZRI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A86KXT0G63WEO: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3HYB9AL7BZY4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2IP8CT8CHOVPB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A14P4UH613ZFQZ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3IY9IIH8P3UU0: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1LV6ASU8XVF1B: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AVTQB8FI2KW8Q: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1RCAVB38E41CR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A357EQO27VKAF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A278MXX9V8LAOP: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2KJPYAJ3CPNMS: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A25R7RXYIO82EO: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AQZ64R6S3R1VF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AARN9RQDNHW9T: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A238IX6INYRVX4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A235NH17AAKX6I: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AMOUCAFH0MKJV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A22S7D0LP8GRDH: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2CXV6PTJCX3AM: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AT1J73L759KWF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2DA2NJZ2RIYAB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1VEFYYTYHFSVQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3SAC4F5WPZDBV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A16AXQ11SZA8SQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3O37N1EDT5RCN: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AY12DBB0U420B: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A39JNWWX6LI6VE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3IVTAT62XST8A: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3DFMKBGQT9QIH: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A210UABBSBQTFL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A5VGCYS7J6JVG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A24BB7ZQSVFD92: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AT6CZDCP4TRGA: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AK4Z9GYV1620S: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A322AOTMV72JED: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A795DMNCJILA6: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A16ZTSR8M5J5G2: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3NLJZI5NEOT0K: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AW4NFCPN81CS3: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2FJLSKL2IZSHC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3S5IJS83L1UAE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A384RYAHGEPLJ8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1ZOL59JA86C7Y: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1ZR6YCZ3HDDKI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A6VXZ1EEPRTLV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2NDDUI5L26D3Q: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3ANKK0ES1RRKJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3W2VH8BN66IIR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1XWDEQMZMPCIH: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A16AL32R7ZZVXB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1WCZ1EBA7KN0U: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ARW1MQYTDO8KM: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ABYVXJZ41TCS4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3STJPJ06CMRVF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1IVNZD0A4AMAG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ANI27DZ63ERTJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2HWCU87BKZ8M0: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1TUT3W4Q9KN8E: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AKUJQJDRIIF1C: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1W1UTQ5SZNE8J: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1WR5OUT03E3M8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2J0C6R7VT8YYS: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3VIP4N73D8CHX: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A96JD9312DHWC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2NB2E5DXE319Z: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A249G4SVEWV9UX: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AN81JUYW2SL24: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AF1IU3K4DB1XI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2NV86LTJDQ2BB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2ZQ4KOUTQIW4O: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2LLGLMTGAQ8B4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AO3M6LS4V3UY4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1QXR4HL9JW1HI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A7AO0PBCKSW82: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A35YAEKTV8E88X: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AQ8OO59DJFJNZ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1X7MYGFDWPGMP: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A13DHT9IJA4J13: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A13Y9OKTACHC31: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A20NUAFQ658EGG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A4PPZNQF1X2IY: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2FDUFFMTO735I: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2QCE7L6GRE3MT: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2NYHM6TRVG9HD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AIWZ5N7D5RCA5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A30TZBEYTQK723: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3I8M4DUWMC9XN: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1J482FVR1LR6P: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AS8K56AC5KOHS: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AU1BBVHPHD0KC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3IKLTT9JQACCI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3KMEQP8CSCPC2: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2V8X8MTCE868O: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2WDC81C1MQUAS: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2RQOO8VYAEZZG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3DZT870KCFD1: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AJA8J1GZ35AOI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2MF4TISBBQT5A: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3SMR4HRFJARSC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A38CKQUHA9POY0: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A14R9XMZVJ6INB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A4T10LCCYXO6S: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2YEOR4XJ8N3QE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2IVEQ5ZV6CGSY: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3AH9AMOC31MDZ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A24KZL47I6CH4C: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3OBJGGKN1KREP: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3P738KVXL2YYM: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2QS3RG1ZA9F73: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3P89EMO989X9D: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1HQP7190B0WJU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AP1PKZ1IXQ7F: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3V39KWHCBSF30: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2O9HU1K7TCF7B: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2WRLYVFFMHKZE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3B143RS9OTU6F: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ATYMCRS041WY8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AJUY84BOITKAB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2BFIWQ9V11A13: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2MF2QVSCUI27G: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2E1BQDLHYGTNV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3LLMXR3QJR60T: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A11P853U6FIKAM: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1JY6HFCL4PZI4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A18Y6RF6S79076: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2T5O7MHGONT6S: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2BAAKZHSUGCDP: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1HW31KJ9V89CR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1F5V3LKI7PCUF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3O4LP2WSD8EP1: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2GPEV42IO41CI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A15XY6GGKD3B6D: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3CG93783LP0FO: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2F9D3XTGJF79V: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A17CE3MO8JYW1I: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2KZCKQSFWRJIY: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2VY0D1UGF9EP9: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AY17DZYGNYJ0L: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3CUWRVAKGEFHL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3TYWLLZGB1EDR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1ZSQ0ZRYGPK7D: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ADYED6Z2R1R0Z: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2UM2ABAII4QTT: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1U0RS0JIDAHDM: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1GARI2JT6EAWA: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2YOFCOEKH3KB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A25HRZR92Z74V5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1NZLRAZJGD99W: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1BMLUSDMWX6VO: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2WG33SBOT901X: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1TPW86OHXTXFC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3G53293E5J9PZ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2RQ5IRWRU0TVO: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AECD1QOMZ2F2I: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A27Y2DPA6F5KRA: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A28SW1AQI0RADX: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3U8JEL4LAZK48: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1GJLMR86MCLEF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A19MNDA2S6L0YJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A34R4EEYB1W0DJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3IQ0P3M39IY8U: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A357B3PUHSVQA: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ATANE2SC44592: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1CRBY1WP9LNJP: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1RNF284ZJY2CL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A25FFSP776JCCA: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AODAJ78KA1MFO: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2OB8HLPIZ6GVC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1Q9Q0EAC3TB02: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A22BC4FPEF0P1J: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AQ3DRB3P7PUEF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A18TJPNGP9L2TF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1UOS0IM2GP87S: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A22F9L73A92U6B: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AFHVXMQFYIXZR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3FVAHYWXWHWG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AVCAXJ845TL8S: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3IH73YPH07FTP: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AU5MPGZYJL31G: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AFVZ6Y9P6AVED: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AJBDDVXOKCM17: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AHLVLW2TZX1LA: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2XV7EIBRJFKXH: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A4UWNRY0WWECK: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A26GHQOTRZMGG8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AQR8MEGW6A81G: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A21GBA652Y58BJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1XHQPFF3SY8QV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1JOANG98KBFKU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3NSV1V2LDJFO7: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A32JK2YET8IFG7: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3U10P2GT1GE1Y: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1LT13C3BKQ9CU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3HUO6O1NQ5JPA: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AONUCJBC85BL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1Z7I6TXMXFP3G: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AGARMSTYE4ZYE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2WVEBYYZXU3LQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ASI65UKWLTDJQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2ZT71NTN85ZV8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1SNSPHCEXV5RL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2VW1QYZOELXS3: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1G0GENIREH10H: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2H5U8EDKQEFXZ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A609XZULHDBSQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A6GY1BZC9X6DZ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A21G2H64TFS4JO: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A33CY1MZDI8944: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2MHCZISNWHQFR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1TKZM4ZQXC4HY: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3BO9I25753U4C: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1WQM564J3V3P2: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3LDLV1GWQJLEQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1YPYJW1LA34QD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3FSPSSTLOD4VU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A28OB1QLXN5BM6: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3OZX99L2HZQUC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A4S8JJMA33F2B: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A29RLU2QCSKBVJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2GVVM2XN8O5ZF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AKE6DXEN3GWPC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AUNHIYLFWWHET: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/APIP4IPEAVCGR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2DKS09X7XXTKQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3LCVGMQD8HK43: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ASQKJ3TO3EOMK: Found results for 3 seeds
# ...
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2NU0FM3MS15EB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AELO6EASJBCVV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AD2QRU9ZXBQZ1: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AW3VZ5O895LRK: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3V61K0EF38GP4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A23E9QQHJLNGUI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3LW8GY42A4URK: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A36EDWL4F3AASU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3MW8B6I2LXVWR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3QP4NYOGQ350K: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AOEUN9718KVRD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1OR7X6Y41D32O: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ABVIQ0W19DPSG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2YOYGGXZCSZ30: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3QYDL5CDNYN66: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AXAA7WYV0T785: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2EK26DJHJJCS3: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A212QA30WPM5PC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3GZM06IX0659S: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ACUJMLOJEVYTB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1RAT2F4TCZA3E: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1IH7O6EL7SNBD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A36AIW5KPEKEHQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3C0F61L558DQE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2KGKNQHOK4C8A: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AMCZLPIRP0QTE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1I4JZLPZF6ZLI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3MZMZXHKSDFKG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3OW27FYEBXXES: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/APEU238DV9WNE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2X75UXQLLI32H: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3I5J6JJHQY7H7: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A27VAEBHL9FQDV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AXM5ZEK9I7CWL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A26T2MC3VCLVYB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1ZRNYBXYZ69ZX: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3PAO2ZX54VV6J: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1PBCZ7A40BTG6: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A13QONG1RD57UW: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2H44WVZS59KKT: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A14VYB264WN1PM: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2I4SQOSEF7WH5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1FWGW8LGG2J37: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2XHH5DF8628J8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1AXSZYFRA93RC: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AIIGP665FWL0E: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A8D5V9VSF6H16: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2Y9088O384NIW: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3DQU9H0AN61Q6: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2O9V03Z8GRIAI: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A29A1CPI3AOYSD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AQPW1HHNJRPGF: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A26NG8QVBF5527: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A26CCG8A3KB7J8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2LQ06A44GOP6E: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1ZZZT0KJR46UV: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3H9JSM1SUTE4O: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1B2L5BDVP7KRM: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2PGJP6GV2ZC02: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2IBF31N8P9FPJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3JIH8AAZLQQ4O: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A67ZXSOC2XH4O: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A20IYX6BSPQ5PR: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1C97CZ8GVFMY5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1EXGL6L0QQ0M5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AL1WTXQJCKT8X: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AYT4FJYVCHYLE: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2QHM5HBSIXRL4: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2ZUMHFY3XJ8DT: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AUUFW7PTUHLT: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A6ADO7B6FUVN: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A34BRH9R7DHXWU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2LC2RS0HDY2FB: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3HU2WUBWT20P8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3M1PLEYNDEYO8: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/ANT80RNKZGHFJ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1XC6NAEF7RKZ0: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A10O7THJ2O20AG: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1SBQ0F7FSLWB0: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AAEIK0DZ1F537: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AZZV9PDNMCOZW: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AJX9A4Q19UTJU: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1X054KUYG5V: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A4X56LVVL2X2U: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1ZSMVTKEFEA8C: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1V4LZS4HHHH6K: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2VTAR3P8C0LBD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AU45V4AMZVHFL: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1UAO54QQBULXD: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A1LZQPBALDJ0Y5: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A2ZJHEB8K8JZR3: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A3O22PG4MHDI4Y: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/A101S5PLO0VRHQ: Found results for 3 seeds
# Base dir /data/ddmg/redditlanguagemodeling/results/amazon_reviews/clf/from_embeds/person_specific_my_split_n_500_early_stopping/AJ84EHI62LNDE: Found results for 3 seeds

# %%
# examine performance
user_results_ps = ps_results.results_df.groupby(["user"]).agg(["mean", "std"])[["test_loss", "test_accuracy"]]
user_results_ps
# Out:
#                test_loss           test_accuracy
#                     mean       std          mean       std
# user
# A101S5PLO0VRHQ  1.057531  0.014976      0.571429  0.000000
# A10E0V7PGY34UZ  0.240300  0.003728      0.933333  0.000000
# A10O7THJ2O20AG  0.649746  0.005187      0.800000  0.000000
# A11P853U6FIKAM  1.055255  0.004417      0.385965  0.000000
# A12O5K3EQ4MC7Z  0.738925  0.007110      0.705882  0.019608
# ...                  ...       ...           ...       ...
# AYT4FJYVCHYLE   1.220608  0.017522      0.288889  0.076980
# AYVW3O6W8S5S4   1.252717  0.033645      0.600000  0.000000
# AZD488SA9QMYF   0.239735  0.006056      0.933333  0.000000
# AZJ4DFLH9O4FZ   0.560942  0.018114      0.666667  0.000000
# AZZV9PDNMCOZW   1.345622  0.026327      0.466667  0.115470
#
# [500 rows x 4 columns]

# %%
print(user_results_ps.mean())
print(user_results_ps.std())
# Out:
# test_loss      mean    0.684446
#                std     0.011241
# test_accuracy  mean    0.722472
#                std     0.011299
# dtype: float64
# test_loss      mean    0.370047
#                std     0.012054
# test_accuracy  mean    0.180346
#                std     0.021178
# dtype: float64

# %%
user_results_ps.quantile(q=[0, .2, .4, .6, .8, 1])
# Out:
#          loss            accuracy
#          mean       std      mean       std
# 0.0  0.006371  0.000023  0.200000  0.000000
# 0.2  0.376093  0.003210  0.555556  0.000000
# 0.4  0.581101  0.006072  0.682803  0.000000
# 0.6  0.761795  0.010643  0.798125  0.000000
# 0.8  0.996006  0.016626  0.873413  0.022553
# 1.0  2.207498  0.144460  1.000000  0.176383

# %% [markdown]
# ### Per-User Differences in Method Performance

# %%
global_df2.head(5)
# Out:
# result          accuracy                loss
#                     mean       std      mean       std
# user
# A101S5PLO0VRHQ  0.476190  0.016496  1.120820  0.012142
# A10E0V7PGY34UZ  0.933333  0.000000  0.384862  0.028398
# A10O7THJ2O20AG  0.577778  0.038490  1.242837  0.030466
# A11P853U6FIKAM  0.502924  0.010129  0.935463  0.009915
# A12O5K3EQ4MC7Z  0.745098  0.000000  0.725279  0.015350

# %%
user_results_ps = user_results_ps.rename(columns={'test_loss': 'loss', 'test_accuracy': 'accuracy'})
user_results_ps.head(5)
# Out:
#                     loss            accuracy
#                     mean       std      mean       std
# user
# A101S5PLO0VRHQ  1.057531  0.014976  0.571429  0.000000
# A10E0V7PGY34UZ  0.240300  0.003728  0.933333  0.000000
# A10O7THJ2O20AG  0.649746  0.005187  0.800000  0.000000
# A11P853U6FIKAM  1.055255  0.004417  0.385965  0.000000
# A12O5K3EQ4MC7Z  0.738925  0.007110  0.705882  0.019608

# %%
# add results from all methods to shared dataframe
combined_results = user_results_ps.merge(global_df2, how='inner', left_index=True, right_index=True, suffixes=["_local", "_global"])

# %%
combined_results.head()
# Out:
#                loss_local           accuracy_local           accuracy_global  \
#                      mean       std           mean       std            mean
# user
# A101S5PLO0VRHQ   1.057531  0.014976       0.571429  0.000000        0.476190
# A10E0V7PGY34UZ   0.240300  0.003728       0.933333  0.000000        0.933333
# A10O7THJ2O20AG   0.649746  0.005187       0.800000  0.000000        0.577778
# A11P853U6FIKAM   1.055255  0.004417       0.385965  0.000000        0.502924
# A12O5K3EQ4MC7Z   0.738925  0.007110       0.705882  0.019608        0.745098
#
#                          loss_global
#                      std        mean       std
# user
# A101S5PLO0VRHQ  0.016496    1.120820  0.012142
# A10E0V7PGY34UZ  0.000000    0.384862  0.028398
# A10O7THJ2O20AG  0.038490    1.242837  0.030466
# A11P853U6FIKAM  0.010129    0.935463  0.009915
# A12O5K3EQ4MC7Z  0.000000    0.725279  0.015350

# %%
train_mc_df = train_mc_df.rename(columns={"reviewerID": "user", "perf": "accuracy_train_majority_cls"}).set_index('user')
train_prob_df = train_prob_df.rename(columns={"reviewerID": "user", "perf": "loss_train_prob_baseline"}).set_index('user')
test_mc_df = test_mc_df.reset_index().rename(columns={"reviewerID": "user", "overall": "accuracy_test_majority_cls"}).set_index('user')
test_prob_df = test_prob_df.rename(columns={"reviewerID": "user", "perf": "loss_test_prob_baseline"}).set_index('user')

# %%
# add in baselines
for df in [train_mc_df, train_prob_df, test_mc_df, test_prob_df]:
    combined_results = combined_results.merge(df, how='inner', left_index=True, right_index=True)
# Out:
# /data/ddmg/users/kmatton/.conda/envs/rlm/lib/python3.8/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
combined_results
# Out:
#                 (loss_local, mean)  (loss_local, std)  (accuracy_local, mean)  \
# user
# A101S5PLO0VRHQ            1.057531           0.014976                0.571429
# A10E0V7PGY34UZ            0.240300           0.003728                0.933333
# A10O7THJ2O20AG            0.649746           0.005187                0.800000
# A11P853U6FIKAM            1.055255           0.004417                0.385965
# A12O5K3EQ4MC7Z            0.738925           0.007110                0.705882
# ...                            ...                ...                     ...
# AYT4FJYVCHYLE             1.220608           0.017522                0.288889
# AYVW3O6W8S5S4             1.252717           0.033645                0.600000
# AZD488SA9QMYF             0.239735           0.006056                0.933333
# AZJ4DFLH9O4FZ             0.560942           0.018114                0.666667
# AZZV9PDNMCOZW             1.345622           0.026327                0.466667
#
#                 (accuracy_local, std)  (accuracy_global, mean)  \
# user
# A101S5PLO0VRHQ               0.000000                 0.476190
# A10E0V7PGY34UZ               0.000000                 0.933333
# A10O7THJ2O20AG               0.000000                 0.577778
# A11P853U6FIKAM               0.000000                 0.502924
# A12O5K3EQ4MC7Z               0.019608                 0.745098
# ...                               ...                      ...
# AYT4FJYVCHYLE                0.076980                 0.666667
# AYVW3O6W8S5S4                0.000000                 0.333333
# AZD488SA9QMYF                0.000000                 0.933333
# AZJ4DFLH9O4FZ                0.000000                 0.622222
# AZZV9PDNMCOZW                0.115470                 0.577778
#
#                 (accuracy_global, std)  (loss_global, mean)  \
# user
# A101S5PLO0VRHQ                0.016496             1.120820
# A10E0V7PGY34UZ                0.000000             0.384862
# A10O7THJ2O20AG                0.038490             1.242837
# A11P853U6FIKAM                0.010129             0.935463
# A12O5K3EQ4MC7Z                0.000000             0.725279
# ...                                ...                  ...
# AYT4FJYVCHYLE                 0.000000             0.636464
# AYVW3O6W8S5S4                 0.000000             1.614175
# AZD488SA9QMYF                 0.000000             0.262011
# AZJ4DFLH9O4FZ                 0.038490             0.609930
# AZZV9PDNMCOZW                 0.038490             1.092888
#
#                 (loss_global, std)  accuracy_train_majority_cls  \
# user
# A101S5PLO0VRHQ            0.012142                     0.314286
# A10E0V7PGY34UZ            0.028398                     0.933333
# A10O7THJ2O20AG            0.030466                     0.800000
# A11P853U6FIKAM            0.009915                     0.421053
# A12O5K3EQ4MC7Z            0.015350                     0.392157
# ...                            ...                          ...
# AYT4FJYVCHYLE             0.019655                     0.333333
# AYVW3O6W8S5S4             0.035395                     0.533333
# AZD488SA9QMYF             0.016293                     0.933333
# AZJ4DFLH9O4FZ             0.028343                     0.333333
# AZZV9PDNMCOZW             0.043024                     0.533333
#
#                 loss_train_prob_baseline  accuracy_test_majority_cls  \
# user
# A101S5PLO0VRHQ                  1.537137                    0.314286
# A10E0V7PGY34UZ                  0.248242                    0.933333
# A10O7THJ2O20AG                  2.846510                    0.800000
# A11P853U6FIKAM                  1.679051                    0.421053
# A12O5K3EQ4MC7Z                  1.075978                    0.411765
# ...                                  ...                         ...
# AYT4FJYVCHYLE                   1.333598                    0.466667
# AYVW3O6W8S5S4                   3.202199                    0.533333
# AZD488SA9QMYF                   0.244930                    0.933333
# AZJ4DFLH9O4FZ                   1.331867                    0.400000
# AZZV9PDNMCOZW                   5.631536                    0.533333
#
#                 loss_test_prob_baseline
# user
# A101S5PLO0VRHQ                 1.471413
# A10E0V7PGY34UZ                 0.244930
# A10O7THJ2O20AG                 0.720125
# A11P853U6FIKAM                 1.107927
# A12O5K3EQ4MC7Z                 1.051915
# ...                                 ...
# AYT4FJYVCHYLE                  1.171060
# AYVW3O6W8S5S4                  1.136917
# AZD488SA9QMYF                  0.244930
# AZJ4DFLH9O4FZ                  1.085189
# AZZV9PDNMCOZW                  1.321756
#
# [500 rows x 12 columns]

# %%
# get difference in global vs local perf
combined_results['global-local_loss'] = combined_results[('loss_global', 'mean')] - combined_results[('loss_local', 'mean')]

# %%
combined_results['global-local_acc'] = combined_results[('accuracy_global', 'mean')] - combined_results[('accuracy_local', 'mean')]

# %%
# look at raw differences
print(combined_results[['global-local_loss', 'global-local_acc']].abs().mean())
print(combined_results[['global-local_loss', 'global-local_acc']].abs().std())
print(combined_results[['global-local_loss', 'global-local_acc']].abs().quantile(q=[0, .2, .4, .6, .8, 1]))
# Out:
# global-local_loss    0.163934
# global-local_acc     0.091426
# dtype: float64
# global-local_loss    0.177669
# global-local_acc     0.102404
# dtype: float64
#      global-local_loss  global-local_acc
# 0.0           0.000238          0.000000
# 0.2           0.038691          0.021692
# 0.4           0.076750          0.044444
# 0.6           0.144716          0.087675
# 0.8           0.255571          0.155556
# 1.0           1.498613          0.866667

# %%
# looks at differences between each model and baselines
combined_results['global-test_prob_dist_loss'] = combined_results[('loss_global', 'mean')] - combined_results['loss_test_prob_baseline']
combined_results['global-train_prob_dist_loss'] = combined_results[('loss_global', 'mean')] - combined_results['loss_train_prob_baseline']
combined_results['local-test_prob_dist_loss'] = combined_results[('loss_local', 'mean')] - combined_results['loss_test_prob_baseline']
combined_results['local-train_prob_dist_loss'] = combined_results[('loss_local', 'mean')] - combined_results['loss_train_prob_baseline']

# %%
print(combined_results[['global-test_prob_dist_loss', 'local-test_prob_dist_loss']].mean())
print(combined_results[['global-test_prob_dist_loss', 'local-test_prob_dist_loss']].std())
print(combined_results[['global-test_prob_dist_loss', 'local-test_prob_dist_loss']].quantile(q=[0, .2, .4, .6, .8, 1]))
# Out:
# global-test_prob_dist_loss   -0.068330
# local-test_prob_dist_loss    -0.106253
# dtype: float64
# global-test_prob_dist_loss    0.324465
# local-test_prob_dist_loss     0.222716
# dtype: float64
#      global-test_prob_dist_loss  local-test_prob_dist_loss
# 0.0                   -1.067018                  -0.960262
# 0.2                   -0.336674                  -0.282308
# 0.4                   -0.151714                  -0.128114
# 0.6                   -0.001755                  -0.021003
# 0.8                    0.157169                   0.056009
# 1.0                    1.389568                   0.885743

# %%
print(combined_results[['global-train_prob_dist_loss', 'local-train_prob_dist_loss']].mean())
print(combined_results[['global-train_prob_dist_loss', 'local-train_prob_dist_loss']].std())
print(combined_results[['global-train_prob_dist_loss', 'local-train_prob_dist_loss']].quantile(q=[0, .2, .4, .6, .8, 1]))
# Out:
# global-train_prob_dist_loss   -0.433828
# local-train_prob_dist_loss    -0.471752
# dtype: float64
# global-train_prob_dist_loss    0.901789
# local-train_prob_dist_loss     0.823324
# dtype: float64
#      global-train_prob_dist_loss  local-train_prob_dist_loss
# 0.0                    -6.698675                   -6.290011
# 0.2                    -0.618539                   -0.531391
# 0.4                    -0.304541                   -0.288254
# 0.6                    -0.117212                   -0.138281
# 0.8                     0.057346                   -0.012891
# 1.0                     1.366611                    0.198085
