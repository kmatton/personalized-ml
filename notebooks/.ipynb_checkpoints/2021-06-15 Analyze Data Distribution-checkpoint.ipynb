# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("../src/")
import json

import numpy as np
import pandas as pd
import math
from datasets import Dataset, list_metrics, load_metric
from transformers import AutoConfig, AutoTokenizer, AutoModelForMaskedLM, DataCollatorForLanguageModeling, Trainer

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
data_df = pd.read_csv("/data/ddmg/personalizedmentalhealth/reddit_project/data/4_all_data.csv")

# %%
data_df.drop(columns="Unnamed: 0", inplace=True)

# %%
data_df = data_df.sort_values('author')

# %%
train_df = data_df[data_df["data_split"] == "train"]
val_df = data_df[data_df["data_split"] == "val"]
test_df = data_df[data_df["data_split"] == "test"]

# %% [markdown]
# # Analyze by Subreddit

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=train_df, x="subreddit")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=val_df, x="subreddit")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=test_df, x="subreddit")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.show()

# %% [markdown]
# # Analyze By Author

# %%
author_set = sorted(list(set(test_df["author"].to_numpy())))

# %%
len(author_set)
# Out:
# 596

# %%
train_df = train_df[train_df["author"].isin(author_set)]

# %%
# map author names to ids
author_2_id = {a: idx for idx, a in enumerate(author_set)}

# %%
train_df["author_id"] = train_df["author"].apply(lambda x: author_2_id[x])

# %%
# analyze distribution by author (just for test authors)
plt.figure(figsize=(16,8))
sns.histplot(data=temp_train, x="author")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light' 
)
plt.show()
