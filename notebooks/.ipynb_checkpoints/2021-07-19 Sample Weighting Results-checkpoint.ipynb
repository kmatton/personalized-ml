# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("../src/")
import json

import numpy as np
import pandas as pd
import math
from scipy.stats import ttest_rel, ttest_ind
from datasets import Dataset, list_metrics, load_metric
from transformers import AutoConfig, AutoTokenizer, AutoModelForMaskedLM, DataCollatorForLanguageModeling, Trainer

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

from results_analysis.analyze_exp_results import ExpAnalyzer

from runners.runner_utils import loss_to_perplexity

# %%
base_result_dir = "/data/ddmg/redditlanguagemodeling/results/5_test_users"

# %%
exp_analyzer = ExpAnalyzer(base_result_dir, ["exp", "target_user", "seed"])

# %%
exp_analyzer.author_result_df
# Out:
#                 author      loss  perplexity                     exp  \
# 0          Creative310  3.261148   26.079465            1_pretrained
# 1           binarygold  3.108351   22.384108            1_pretrained
# 2       bluejeans90210  2.590883   13.341547            1_pretrained
# 3           escapevelo  3.340231   28.225658            1_pretrained
# 4     retardedinvestor  4.183322   65.583388            1_pretrained
# ..                 ...       ...         ...                     ...
# 45        robert323445  1.646320    5.187854  3_weight_target_user_6
# 46              skabaw  2.561750   12.958474  3_weight_target_user_6
# 47          svet_sedov  2.395413   10.972733  3_weight_target_user_6
# 48               wsace  1.977342    7.223517  3_weight_target_user_6
# 49  your_godammn_right  2.731966   15.363061  3_weight_target_user_6
#
#          target_user seed
# 0               none   42
# 1               none   42
# 2               none   42
# 3               none   42
# 4               none   42
# ..               ...  ...
# 45  retardedinvestor   46
# 46  retardedinvestor   46
# 47  retardedinvestor   46
# 48  retardedinvestor   46
# 49  retardedinvestor   46
#
# [4380 rows x 6 columns]

# %% [markdown]
# ## Analyze Performance for each of our 5 test users

# %% [markdown]
# #### R* Investor

# %%
ri_user_df = exp_analyzer.author_result_df[exp_analyzer.author_result_df["author"] == "retardedinvestor"]

# %%
ri_user_df = ri_user_df[ri_user_df["target_user"].isin(["none", "retardedinvestor"])]

# %%
# all tests have finished for this user!

# %%
len(ri_user_df)
# Out:
# 41

# %%
ri_user_df[ri_user_df["exp"] == "3_weight_target_user_1"]
# Out:
#               author      loss  perplexity                     exp  \
# 44  retardedinvestor  5.502622  245.334388  3_weight_target_user_1
# 44  retardedinvestor  4.745125  115.022216  3_weight_target_user_1
# 44  retardedinvestor  5.965725  389.835721  3_weight_target_user_1
# 44  retardedinvestor  5.282963  196.952543  3_weight_target_user_1
# 44  retardedinvestor  5.813533  334.799989  3_weight_target_user_1
#
#          target_user seed
# 44  retardedinvestor   43
# 44  retardedinvestor   44
# 44  retardedinvestor   46
# 44  retardedinvestor   45
# 44  retardedinvestor   42

# %%
sns.barplot(data=ri_user_df, x="exp", y="perplexity")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.show()

# %%
sns.barplot(data=ri_user_df[ri_user_df["exp"] != "3_weight_target_user_1"], x="exp", y="perplexity")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.show()

# %% [markdown]
# #### BinaryGold

# %%
bg_user_df = exp_analyzer.author_result_df[exp_analyzer.author_result_df["author"] == "binarygold"]

# %%
bg_user_df = bg_user_df[bg_user_df["target_user"].isin(["none", "binarygold"])]

# %%
# missing 8 --> 4 from sample weight .25 and 4 from sample weight .6
len(bg_user_df)
# Out:
# 33

# %%
sns.barplot(data=bg_user_df, x="exp", y="perplexity")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.show()

# %%
sns.barplot(data=bg_user_df[bg_user_df["exp"] != "3_weight_target_user_1"], x="exp", y="perplexity")
plt.tight_layout()
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.show()

# %% [markdown]
# #### Creative310

# %%
def get_user_df(result_df, user_name):
    df = result_df[result_df["author"] == user_name]
    df = df[df["target_user"].isin(["none", user_name])]
    return df
